# %%
from langchain.document_loaders import UnstructuredHTMLLoader
loader = UnstructuredHTMLLoader("demo.html")
data = loader.load()
data
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11004]
# [nltk_data]     getaddrinfo failed>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[21], line 3
#       1 from langchain.document_loaders import UnstructuredHTMLLoader
#       2 loader = UnstructuredHTMLLoader("demo.html")
# ----> 3 data = loader.load()
#       4 data
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_core\document_loaders\base.py:29, in BaseLoader.load(self)
#      27 def load(self) -> List[Document]:
#      28     """Load data into Document objects."""
# ---> 29     return list(self.lazy_load())
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_community\document_loaders\unstructured.py:88, in UnstructuredBaseLoader.lazy_load(self)
#      86 def lazy_load(self) -> Iterator[Document]:
#      87     """Load file."""
# ---> 88     elements = self._get_elements()
#      89     self._post_process_elements(elements)
#      90     if self.mode == "elements":
#
# File G:\Program Files\anaconda3\Lib\site-packages\langchain_community\document_loaders\html.py:33, in UnstructuredHTMLLoader._get_elements(self)
#      30 def _get_elements(self) -> List:
#      31     from unstructured.partition.html import partition_html
# ---> 33     return partition_html(filename=self.file_path, **self.unstructured_kwargs)
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\documents\elements.py:526, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     524 @functools.wraps(func)
#     525 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 526     elements = func(*args, **kwargs)
#     527     sig = inspect.signature(func)
#     528     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\file_utils\filetype.py:627, in add_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     625 @functools.wraps(func)
#     626 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 627     elements = func(*args, **kwargs)
#     628     sig = inspect.signature(func)
#     629     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\file_utils\filetype.py:582, in add_metadata.<locals>.wrapper(*args, **kwargs)
#     580 @functools.wraps(func)
#     581 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> List[Element]:
# --> 582     elements = func(*args, **kwargs)
#     583     sig = inspect.signature(func)
#     584     params: Dict[str, Any] = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\chunking\__init__.py:71, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      68     return call_args
#      70 # -- call the partitioning function to get the elements --
# ---> 71 elements = func(*args, **kwargs)
#      73 # -- look for a chunking-strategy argument and run the indicated chunker when present --
#      74 call_args = get_call_args_applying_defaults()
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\partition\html.py:141, in partition_html(filename, file, text, url, encoding, include_page_breaks, include_metadata, headers, ssl_verify, parser, source_format, html_assemble_articles, metadata_filename, metadata_last_modified, skip_headers_and_footers, chunking_strategy, languages, detect_language_per_element, detection_origin, **kwargs)
#     136 if skip_headers_and_footers:
#     137     document = filter_footer_and_header(document)
#     139 return list(
#     140     apply_lang_metadata(
# --> 141         document_to_element_list(
#     142             document,
#     143             sortable=False,
#     144             include_page_breaks=include_page_breaks,
#     145             last_modification_date=metadata_last_modified or last_modification_date,
#     146             source_format=source_format if source_format else None,
#     147             detection_origin=detection_origin,
#     148             **kwargs,
#     149         ),
#     150         languages=languages,
#     151         detect_language_per_element=detect_language_per_element,
#     152     ),
#     153 )
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\partition\common.py:559, in document_to_element_list(document, sortable, include_page_breaks, last_modification_date, infer_list_items, source_format, detection_origin, sort_mode, languages, **kwargs)
#     556 """Converts a DocumentLayout object to a list of unstructured elements."""
#     557 elements: List[Element] = []
# --> 559 num_pages = len(document.pages)
#     560 for i, page in enumerate(document.pages):
#     561     page_elements: List[Element] = []
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\documents\xml.py:54, in XMLDocument.pages(self)
#      52 """Gets all elements from pages in sequential order."""
#      53 if self._pages is None:
# ---> 54     self._pages = self._parse_pages_from_element_tree()
#      55 return super().pages
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\documents\html.py:176, in HTMLDocument._parse_pages_from_element_tree(self)
#     173             page.elements.append(element)
#     175 else:
# --> 176     element = _parse_tag(tag_elem)
#     177     if element is not None:
#     178         page.elements.append(element)
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\documents\html.py:423, in _parse_tag(tag_elem)
#     421 if not text:
#     422     return None
# --> 423 return _text_to_element(
#     424     text,
#     425     tag_elem.tag,
#     426     ancestortags,
#     427     links=links,
#     428     emphasized_texts=emphasized_texts,
#     429     depth=depth,
#     430 )
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\documents\html.py:471, in _text_to_element(text, tag, ancestortags, depth, links, emphasized_texts)
#     469 if len(text) < 2:
#     470     return None
# --> 471 elif is_narrative_tag(text, tag):
#     472     return HTMLNarrativeText(
#     473         text,
#     474         tag=tag,
#    (...)
#     477         emphasized_texts=emphasized_texts,
#     478     )
#     479 elif is_heading_tag(tag) or is_possible_title(text):
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\documents\html.py:519, in is_narrative_tag(text, tag)
#     517 def is_narrative_tag(text: str, tag: str) -> bool:
#     518     """Uses tag information to infer whether text is narrative."""
# --> 519     return tag not in HEADING_TAGS and is_possible_narrative_text(text)
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\partition\text_type.py:78, in is_possible_narrative_text(text, cap_threshold, non_alpha_threshold, languages, language_checks)
#      73 # NOTE(robinson): it gets read in from the environment as a string so we need to
#      74 # cast it to a float
#      75 cap_threshold = float(
#      76     os.environ.get("UNSTRUCTURED_NARRATIVE_TEXT_CAP_THRESHOLD", cap_threshold),
#      77 )
# ---> 78 if exceeds_cap_ratio(text, threshold=cap_threshold):
#      79     trace_logger.detail(f"Not narrative. Text exceeds cap ratio {cap_threshold}:\n\n{text}")  # type: ignore # noqa: E501
#      80     return False
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\partition\text_type.py:274, in exceeds_cap_ratio(text, threshold)
#     261 """Checks the title ratio in a section of text. If a sufficient proportion of the words
#     262 are capitalized, that can be indicated on non-narrative text (i.e. "1A. Risk Factors").
#     263
#    (...)
#     270     the function returns True
#     271 """
#     272 # NOTE(robinson) - Currently limiting this to only sections of text with one sentence.
#     273 # The assumption is that sections with multiple sentences are not titles.
# --> 274 if sentence_count(text, 3) > 1:
#     275     return False
#     277 if text.isupper():
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\partition\text_type.py:223, in sentence_count(text, min_length)
#     212 def sentence_count(text: str, min_length: Optional[int] = None) -> int:
#     213     """Checks the sentence count for a section of text. Titles should not be more than one
#     214     sentence.
#     215
#    (...)
#     221         The min number of words a section needs to be for it to be considered a sentence.
#     222     """
# --> 223     sentences = sent_tokenize(text)
#     224     count = 0
#     225     for sentence in sentences:
#
# File G:\Program Files\anaconda3\Lib\site-packages\unstructured\nlp\tokenize.py:30, in sent_tokenize(text)
#      28 """A wrapper around the NLTK sentence tokenizer with LRU caching enabled."""
#      29 _download_nltk_package_if_not_present(package_category="tokenizers", package_name="punkt")
# ---> 30 return _sent_tokenize(text)
#
# File G:\Program Files\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File G:\Program Files\anaconda3\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File G:\Program Files\anaconda3\Lib\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File G:\Program Files\anaconda3\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/english.pickle
#
#   Searched in:
#     - 'C:\\Users\\long/nltk_data'
#     - 'G:\\Program Files\\anaconda3\\nltk_data'
#     - 'G:\\Program Files\\anaconda3\\share\\nltk_data'
#     - 'G:\\Program Files\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\long\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************
