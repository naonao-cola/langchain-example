# %%
from langchain_community.embeddings import FakeEmbeddings

embeddings = FakeEmbeddings(size=1352)
query_result = embeddings.embed_query("AI会对人类文明产生深远影响")
doc_results = embeddings.embed_documents(["AI会对人类文明产生深远影响"])
doc_results
# Out:
# [[0.08802481750350812,
#   -0.5728991954696783,
#   -0.8746633408923626,
#   -0.5522980263029255,
#   -0.4395555463399705,
#   0.5201377737360712,
#   -0.7565272493746099,
#   -1.4329191105728418,
#   0.015063371753114795,
#   0.18774178727267907,
#   2.7438570357253873,
#   -2.6053466679742185,
#   -1.2628830624218277,
#   1.3116901552411748,
#   1.0446593187939324,
#   -1.0338831104450867,
#   -0.9272558841501365,
#   0.1270246656746171,
#   -0.37164618844318076,
#   -2.240034680014272,
#   -0.3545765080297294,
#   -0.6575472855722775,
#   0.38665042903649083,
#   0.29023693792455374,
#   -0.10606368521352137,
#   -0.08242111615215555,
#   1.5461608466607064,
#   -0.03743659053980239,
#   -1.2569540251263025,
#   0.918925375881826,
#   1.3346917835950125,
#   -0.5194105842659963,
#   0.04135583285765504,
#   0.8498788789384292,
#   -0.7661777983376538,
#   -0.9470942779676561,
#   -0.55665757727072,
#   -0.9464410744870733,
#   0.9800983685143273,
#   -0.3029668327009085,
# ...
